# %%
# Check for missing values
print(df.isnull().sum())

# Convert 'Date' to datetime (already in correct format, but good practice)
df['Date'] = pd.to_datetime(df['Date'])

# Create Month-Year column for trend analysis
df['Month_Year'] = df['Date'].dt.to_period('M')

# Check unique values
print(df['Segment'].unique())
print(df['Country'].unique())

# Save the cleaned data
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
#  Sales                 0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# Month_Year             0
# dtype: int64
# ['Government' 'Channel Partners' 'Enterprise' 'Small Business' 'Midmarket']
# ['Mexico' 'France' 'Canada' 'Germany' 'USA']

# %%
df.to_csv('cleaned_file.csv', index=False)
